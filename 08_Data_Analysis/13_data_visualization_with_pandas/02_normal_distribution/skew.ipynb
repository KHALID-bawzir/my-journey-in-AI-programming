# %%
import pandas as pd 
df = pd.read_csv('Students_Marks.csv')
df.describe()
# Out:
#              Id       Math        Phy       Lang
# count  20.00000  20.000000  20.000000  20.000000
# mean   10.50000  57.750000  68.500000  63.250000
# std     5.91608  14.642674  14.876686  11.728844
# min     1.00000  30.000000  40.000000  45.000000
# 25%     5.75000  48.750000  60.000000  53.750000
# 50%    10.50000  60.000000  67.500000  62.500000
# 75%    15.25000  70.000000  80.000000  71.250000
# max    20.00000  80.000000  95.000000  85.000000

# %%
df.plot(kind='kde' , subplots=True , layout=(4,1) , sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>]], dtype=object)

# %%
df.skew()
# Out:
# Id      0.000000
# Math   -0.258904
# Phy    -0.102308
# Lang    0.034591
# dtype: float64

# %%
df.plot(kind='pie' , subplots=True , layout=(4,1) , sharex=False ,figsize=(20,20),
    legend=False)
# Out:
# array([[<Axes: ylabel='Id'>],
#        [<Axes: ylabel='Math'>],
#        [<Axes: ylabel='Phy'>],
#        [<Axes: ylabel='Lang'>]], dtype=object)

# %%
df.plot(kind='area' , subplots=True , layout=(4,1) , sharex=False ,figsize=(20,20),stacked=False
 )
# Out:
# array([[<Axes: >],
#        [<Axes: >],
#        [<Axes: >],
#        [<Axes: >]], dtype=object)

# %%
df.head()
# Out:
#    Id  Math  Phy  Lang
# 0   1    30   40    50
# 1   2    60   65    45
# 2   3    35   60    70
# 3   4    70   75    50
# 4   5    80   80    60

# %%
df.plot(kind='bar' , subplots=True , layout=(4,1) , sharex=False ,figsize=(20,20),
    legend=False)
# Out:
# array([[<Axes: title={'center': 'Id'}>],
#        [<Axes: title={'center': 'Math'}>],
#        [<Axes: title={'center': 'Phy'}>],
#        [<Axes: title={'center': 'Lang'}>]], dtype=object)

# %%
df.plot(kind='barh' , subplots=True , layout=(4,1) , sharex=False ,figsize=(20,20),
    legend=False)
# Out:
# array([[<Axes: title={'center': 'Id'}>],
#        [<Axes: title={'center': 'Math'}>],
#        [<Axes: title={'center': 'Phy'}>],
#        [<Axes: title={'center': 'Lang'}>]], dtype=object)

# %%
df
# Out:
#     Id  Math  Phy  Lang
# 0    1    30   40    50
# 1    2    60   65    45
# 2    3    35   60    70
# 3    4    70   75    50
# 4    5    80   80    60
# 5    6    70   95    70
# 6    7    65   85    60
# 7    8    40   65    45
# 8    9    60   60    65
# 9   10    50   70    75
# 10  11    65   45    60
# 11  12    60   50    65
# 12  13    55   55    70
# 13  14    70   60    75
# 14  15    45   65    80
# 15  16    75   70    55
# 16  17    80   75    85
# 17  18    40   80    50
# 18  19    50   85    60
# 19  20    55   90    75
