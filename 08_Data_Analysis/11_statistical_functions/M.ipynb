# %%
import pandas as pd
df =pd.read_csv('Students_exams.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         1000 non-null   object
#  1   math score     1000 non-null   int64
#  2   reading score  1000 non-null   int64
#  3   writing score  1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
df.count()
# Out:
# gender           1000
# math score       1000
# reading score    1000
# writing score    1000
# dtype: int64

# %%
m = df['math score'].mean()
print(m)
# Out:
# 66.089

# %%
mi = df['math score'].min()
ma = df['math score'].max()
print ('min :' ,mi)
print ('max :' ,ma)
# Out:
# min : 0
# max : 100

# %%
med = df['math score'].median()
print(med)
# Out:
# 66.0

# %%
qua = df['math score'].quantile(0.25)
print(qua)
# Out:
# 57.0

# %%
qua = df['math score'].quantile(0.75)
print(qua)
# Out:
# 77.0

# %%
std = df['math score'].std()
print(std)
# Out:
# 15.163080096009468

# %%
mode = df['math score'].mode()[0]
print(mode)
# Out:
# 65
