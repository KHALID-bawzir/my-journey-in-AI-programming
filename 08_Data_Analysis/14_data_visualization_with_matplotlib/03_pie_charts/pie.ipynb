# %%
import matplotlib.pyplot as plt

# %%
y = [40,20,30,10]
mylabels=['a' , 'b' , 'c' , 'd']
myexplod = [0.2,0.1,0,0]
mycolor=['#800080','#008080','#800000','#808080']
plt.pie(y ,  labels=mylabels  , explode=myexplod ,shadow=True , colors=mycolor )
# Out:
# ([<matplotlib.patches.Wedge at 0x200e58e4690>,
# ...
#  [Text(0.401722049452549, 1.2363734852315638, 'a'),
#   Text(-1.1999999999999955, -1.049073360044697e-07, 'b'),
#   Text(1.311736850028664e-08, -1.0999999999999999, 'c'),
#   Text(1.046162345950534, -0.33991814590467956, 'd')])
