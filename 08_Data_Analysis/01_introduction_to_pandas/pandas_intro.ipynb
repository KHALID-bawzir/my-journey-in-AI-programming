# %%
import pandas as pd 
df = pd.DataFrame([1,2,3,4,5],[11,22,33,44,55] , [111])
print(df)
# Out:
#     111
# 11    1
# 22    2
# 33    3
# 44    4
# 55    5

# %%
data = ['khalid' , 'seed' , 'Ahmed' , 'brok']
df = pd.DataFrame(data , columns=['Name'])
print(df)
# Out:
#      Name
# 0  khalid
# 1    seed
# 2   Ahmed
# 3    brok

# %%
data = [['khalid',11],['seed',23],['Ahmed',45],['brok', 13]] 
df = pd.DataFrame(data ,index=['man1' , 'man2' , 'man3' , 'man4'] ,columns=['name' , 'age'])
print(df)
# Out:
#         name  age
# man1  khalid   11
# man2    seed   23
# man3   Ahmed   45
# man4    brok   13

# %%
data = {'Name': ['Tom', 'Jack', 'Steve', 'Ricky' ], 'Age' : [28,34,29,42]}
df = pd.DataFrame(data)

print(df)

print("======================================")

df.head()
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
# ...
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
