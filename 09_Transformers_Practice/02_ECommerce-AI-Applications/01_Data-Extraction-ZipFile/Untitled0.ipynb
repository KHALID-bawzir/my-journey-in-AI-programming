# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os
import zipfile

zip_file = '/content/drive/MyDrive/TransformesCod/02/UnzipFiles/example[1].zip'
working_folder = '/content/drive/MyDrive/TransformesCod/02/UnzipFiles'

with zipfile.ZipFile(zip_file , 'r') as zip_ref:
  zip_ref.extractall(working_folder)

csv_file = os.path.join(working_folder , 'example.csv')
df = pd.read_csv(csv_file)
df.head()
# Out:
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                          description
# 0  Key Features of Alisha Solid Women's Cycling S...
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2  Key Features of AW Bellies Sandals Wedges Heel...
# 3  Key Features of Alisha Solid Women's Cycling S...
# 4  Specifications of Sicons All Purpose Arnica Do...
